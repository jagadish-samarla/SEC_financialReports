# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadish-samarla/SEC_financialReports/blob/main/SEC_financialReports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import time
from openpyxl import Workbook

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_excel('/content/drive/MyDrive/Datasets/SEC_with_reports.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0  ...                                            reports
# 0           0  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 1           1  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 2           2  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 3           3  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 4           4  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
#
# [5 rows x 9 columns]

# %%
df.tail()
# Out:
#      Unnamed: 0  ...                                            reports
# 147         147  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 148         148  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 149         149  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 150         150  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 151         151  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
#
# [5 rows x 9 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  ...                                            reports
# 0           0  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 1           1  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 2           2  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 3           3  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
# 4           4  ...  [['-----BEGIN PRIVACY-ENHANCED MESSAGE-----\nP...
#
# [5 rows x 9 columns]

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.7/dist-packages (2.5.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: jdcal in /usr/local/lib/python3.7/dist-packages (from openpyxl) (1.4.1)

# %%
import re
import string
import nltk

# %%
file = open('/content/drive/MyDrive/Datasets/StopWords_Generic.txt', 'r')
stopwords = []
for lines in file:
  stopwords.append(lines[:-1])

# %%
stopwords = [word.lower() for word in stopwords]
stopwords
# Out:
# ['about',
#  'above',
#  'after',
#  'again',
#  'all',
#  'am',
#  'among',
#  'an',
#  'and',
#  'any',
#  'are',
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'did',
#  'do',
#  'does',
#  'doing',
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'has',
#  'have',
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'if',
#  'in',
#  'into',
#  'is',
#  'it',
#  'its',
#  'itself',
#  'just',
#  'me',
#  'more',
#  'most',
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'now',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'same',
#  'she',
#  'should',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  'we',
#  'were',
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'with',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselve']

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import word_tokenize

def clean_and_tokenize(text):
  text = "".join([word for word in text if word not in string.punctuation])
  token = word_tokenize(text)
  token = [word for word in token if word not in stopwords]
  return token

df['report_no_stopwords'] = df['reports'].apply(lambda x: clean_and_tokenize(x.lower()))
df.head()
# Out:
#    Unnamed: 0  ...                                report_no_stopwords
# 0           0  ...  [begin, privacyenhanced, messagenproctype, 200...
# 1           1  ...  [begin, privacyenhanced, messagenproctype, 200...
# 2           2  ...  [begin, privacyenhanced, messagenproctype, 200...
# 3           3  ...  [begin, privacyenhanced, messagenproctype, 200...
# 4           4  ...  [begin, privacyenhanced, messagenproctype, 200...
#
# [5 rows x 10 columns]

# %%
#def clean_text(text):
 #   text = "".join([word for word in text if word not in string.punctuation])
  #  tokens1 = re.split('\W+', text)
   # tokens2 = nltk.tokenize(text)
    #text = [word for word in tokens if word not in stopwords]
    #return text

#df['report_no_stopwords'] = df['reports'].apply(lambda x: clean_text(x.lower()))

#df.head()

# %%
df['report_no_stopwords'].loc[1]
# Out:
# ['begin',
#  'privacyenhanced',
#  'messagenproctype',
#  '2001micclearnoriginatorname',
#  'webmasterwwwsecgovnoriginatorkeyasymmetricn',
#  'mfgwcgyevqgbaqicaf8dsgawrwjaw2snkk9avtbzyzmr6agjlwyk3xmzv3dtinenn',
#  'twsm7vrzladbmyqaionwg5sdw3p6oam5d3tdezxmm7z1tbtwidaqabnmicinfo',
#  'rsamd5rsan',
#  'j9lrpfzqdn66tcsh3ivusmxxqj0svrieifllcdbylpa7pfccub40wmy0i1p8n',
#  'maetivhris0tiqixva9k6gnnsecdocument000095017098001001txt',
#  '19980518nsecheader000095017098001001hdrsgml',
#  '19980518naccession',
#  'number',
#  '000095017098001001nconformed',
#  'submission',
#  'type',
#  '10qnpublic',
#  'document',
#  'count',
#  '8nconformed',
#  'period',
#  'report',
#  '19980331nfiled',
#  'date',
#  '19980515nsros',
#  'nysennfilernn',
#  'company',
#  'data',
#  'n',
#  'company',
#  'conformed',
#  'name',
#  'sunbeam',
#  'corpfln',
#  'central',
#  'index',
#  'key',
#  '0000003662n',
#  'standard',
#  'industrial',
#  'classification',
#  'electric',
#  'housewares',
#  'fans',
#  '3634n',
#  'irs',
#  'number',
#  '251638266n',
#  'state',
#  'incorporation',
#  'den',
#  'fiscal',
#  'year',
#  'end',
#  '1229nn',
#  'filing',
#  'valuesn',
#  'form',
#  'type',
#  '10qn',
#  'sec',
#  'act',
#  'n',
#  'sec',
#  'file',
#  'number',
#  '00100052n',
#  'film',
#  'number',
#  '98624818nn',
#  'business',
#  'address',
#  'n',
#  'street',
#  '1',
#  '1615',
#  'south',
#  'congress',
#  'avenuen',
#  'street',
#  '2',
#  'suite',
#  '200n',
#  'city',
#  'delray',
#  'beachn',
#  'state',
#  'fln',
#  'zip',
#  '33445n',
#  'business',
#  'phone',
#  '5612432100nn',
#  'mail',
#  'address',
#  'n',
#  'street',
#  '1',
#  '1615',
#  'south',
#  'congress',
#  'avenuen',
#  'street',
#  '2',
#  'suite',
#  '200n',
#  'city',
#  'delray',
#  'beachn',
#  'state',
#  'fln',
#  'zip',
#  '33445nn',
#  'former',
#  'company',
#  'n',
#  'former',
#  'conformed',
#  'name',
#  'sunbeam',
#  'oster',
#  'company',
#  'inc',
#  'den',
#  'date',
#  'name',
#  'change',
#  '19931210nsecheaderndocumentntype10qnsequence1ntextnnn',
#  'n',
#  'n',
#  'united',
#  'statesn',
#  'securities',
#  'exchange',
#  'commissionn',
#  'washington',
#  'dc',
#  '20549nn',
#  'nn',
#  'form',
#  '10qnn',
#  'x',
#  'quarterly',
#  'report',
#  'pursuant',
#  'section',
#  '13',
#  '15d',
#  'ofn',
#  'securities',
#  'exchange',
#  'act',
#  '1934nn',
#  'period',
#  'ended',
#  'march',
#  '31',
#  '1998nn',
#  'ornn',
#  'transition',
#  'report',
#  'pursuant',
#  'section',
#  '13',
#  '15d',
#  'ofn',
#  'securities',
#  'exchange',
#  'act',
#  '1934nn',
#  'transition',
#  'period',
#  'nn',
#  'commission',
#  'file',
#  'number',
#  '152nn',
#  'sunbeam',
#  'logon',
#  'n',
#  'sunbeam',
#  'corporationn',
#  'exact',
#  'name',
#  'registrant',
#  'specified',
#  'charternn',
#  'delaware',
#  '251638266n',
#  'state',
#  'jurisdiction',
#  'irs',
#  'employern',
#  'incorporation',
#  'organization',
#  'identification',
#  'nonn',
#  '1615',
#  'south',
#  'congress',
#  'avenue',
#  '33445n',
#  'suite',
#  '200',
#  'zip',
#  'coden',
#  'delray',
#  'beach',
#  'floridan',
#  'address',
#  'principal',
#  'executive',
#  'officesn',
#  'n',
#  '561',
#  '2432100n',
#  'registrants',
#  'telephone',
#  'number',
#  'including',
#  'area',
#  'codenn',
#  'applicablen',
#  'former',
#  'name',
#  'former',
#  'address',
#  'former',
#  'fiscal',
#  'year',
#  'changed',
#  'since',
#  'lastn',
#  'reportnn',
#  'indicate',
#  'check',
#  'mark',
#  'whether',
#  'registrant',
#  '1',
#  'filed',
#  'reportsnrequired',
#  'filed',
#  'section',
#  '13',
#  '15d',
#  'securities',
#  'exchange',
#  'act',
#  'ofn1934',
#  'preceding',
#  '12',
#  'months',
#  'shorter',
#  'period',
#  'thenregistrant',
#  'required',
#  'file',
#  'reports',
#  '2',
#  'subject',
#  'suchnfiling',
#  'requirements',
#  'past',
#  '90',
#  'daysnn',
#  'x',
#  'yes',
#  'nonn',
#  'may',
#  '11',
#  '1998',
#  '100824578',
#  'shares',
#  'registrants',
#  'commonnstock',
#  '01',
#  'par',
#  'value',
#  'outstandingnn',
#  'n',
#  'n',
#  'npagenn',
#  'sunbeam',
#  'corporation',
#  'subsidiariesnn',
#  'quarterly',
#  'reportn',
#  'form',
#  '10qnn',
#  'table',
#  'contentsnntablencaptionn',
#  'pagen',
#  'ns',
#  'c',
#  'cnpart',
#  'i',
#  'financial',
#  'informationnn',
#  'item',
#  '1',
#  'financial',
#  'statementsnn',
#  'condensed',
#  'consolidated',
#  'statements',
#  'operations',
#  'unaudited',
#  'threen',
#  'months',
#  'ended',
#  'march',
#  '30',
#  '1997',
#  'march',
#  '31',
#  '1998',
#  '2nn',
#  'condensed',
#  'consolidated',
#  'balance',
#  'sheets',
#  'december',
#  '28',
#  '1997',
#  'andn',
#  'march',
#  '31',
#  '1998',
#  'unaudited',
#  '3nn',
#  'condensed',
#  'consolidated',
#  'statements',
#  'cash',
#  'flows',
#  'unaudited',
#  'three',
#  'months',
#  'ended',
#  'march',
#  '30',
#  '1997',
#  'march',
#  '31',
#  '1998',
#  '4nn',
#  'notes',
#  'condensed',
#  'consolidated',
#  'financial',
#  'statements',
#  'unaudited',
#  '5nn',
#  'item',
#  '2',
#  'managements',
#  'discussion',
#  'analysis',
#  'financial',
#  'condition',
#  'andn',
#  'results',
#  'operations',
#  '10nnpart',
#  'ii',
#  'informationnn',
#  'item',
#  '1',
#  'legal',
#  'proceedings',
#  '14nn',
#  'item',
#  '5',
#  'information',
#  '14nn',
#  'item',
#  '6',
#  'exhibits',
#  'reports',
#  'form',
#  '8k',
#  '14nnsignatures',
#  '15ntablenn',
#  '1npagennpart',
#  'i',
#  'financial',
#  'informationnn',
#  'sunbeam',
#  'corporation',
#  'subsidiariesnn',
#  'condensed',
#  'consolidated',
#  'statements',
#  'operationsn',
#  'thousands',
#  'except',
#  'per',
#  'share',
#  'amountsnntablencaptionn',
#  'three',
#  'months',
#  'endedn',
#  'n',
#  'march',
#  '31',
#  'march',
#  '30n',
#  '1998',
#  '1997n',
#  'n',
#  'unauditedns',
#  'c',
#  'cnnet',
#  'sales',
#  '244296',
#  '253450ncost',
#  'goods',
#  'sold',
#  '211459',
#  '185698nselling',
#  'general',
#  'administrative',
#  'expense',
#  '68841',
#  '33009n',
#  'noperating',
#  'earnings',
#  'loss',
#  '36004',
#  '34743ninterest',
#  'expense',
#  '5072',
#  '1993nother',
#  'expense',
#  'net',
#  '2367',
#  '113n',
#  'nearnings',
#  'loss',
#  'continuing',
#  'operations',
#  'beforen',
#  'extraordinary',
#  'charges',
#  'income',
#  'taxes',
#  '43443',
#  '32637nincome',
#  'taxes',
#  'benefitn',
#  'current',
#  '327',
#  '1052n',
#  'deferred',
#  '4785',
#  '13128n',
#  'n',
#  '4458',
#  '12076n',
#  'nearnings',
#  'loss',
#  'continuing',
#  'operations',
#  '38985',
#  '20561nextraordinary',
#  'charge',
#  'early',
#  'retirement',
#  'debt',
#  'net',
#  'tax',
#  '5608',
#  'nloss',
#  'discontinued',
#  'operations',
#  'net',
#  'tax',
#  '13713n',
#  'nnet',
#  'earnings',
#  'loss',
#  '44593',
#  '6848n',
#  'nearnings',
#  'loss',
#  'per',
#  'share',
#  'continuing',
#  'operationsn',
#  'extraordinary',
#  'charge',
#  'basic',
#  'diluted',
#  '45',
#  '24n',
#  'nearnings',
#  'loss',
#  'per',
#  'share',
#  'basic',
#  'diluted',
#  '52',
#  '08n',
#  'nweighted',
#  'average',
#  'common',
#  'shares',
#  'outstanding',
#  'basic',
#  'diluted',
#  '86390',
#  '86978ndividends',
#  'declared',
#  'per',
#  'share',
#  'common',
#  'stock',
#  '01',
#  '01ntablenn',
#  'see',
#  'notes',
#  'condensed',
#  'consolidated',
#  'financial',
#  'statementsnn',
#  '2npagenn',
#  'sunbeam',
#  'corporation',
#  'subsidiariesnn',
#  'condensed',
#  'consolidated',
#  'balance',
#  'sheetsn',
#  'dollars',
#  'thousandsnntablencaptionn',
#  'march',
#  '31',
#  'december',
#  '28n',
#  '1998',
#  '1997n',
#  'n',
#  'unauditedns',
#  'c',
#  'cnassetsncurrent',
#  'assetsn',
#  'cash',
#  'cash',
#  'equivalents',
#  '193543',
#  '52378n',
#  'receivables',
#  'net',
#  '562294',
#  '295550n',
#  'inventories',
#  '575109',
#  '256180n',
#  'deferred',
#  'income',
#  'taxes',
#  '70782',
#  '36706n',
#  'prepaid',
#  'expenses',
#  'current',
#  'assets',
#  '36910',
#  '17191n',
#  'n',
#  'total',
#  'current',
#  'assets',
#  '1438638',
#  '658005nproperty',
#  'plant',
#  'equipment',
#  'net',
#  '403179',
#  '240897ntrademarks',
#  'trade',
#  'names',
#  'net',
#  '192882',
#  '194372ngoodwill',
#  '1324851',
#  '24750nother',
#  'assets',
#  'including',
#  'deferred',
#  'financing',
#  'costs',
#  '83872',
#  '2260n',
#  'n',
#  '3443422',
#  '1120284n',
#  'nnliabilities',
#  'shareholders',
#  'equityncurrent',
#  'liabilitiesn',
#  'shortterm',
#  'debt',
#  'current',
#  'portion',
#  'longterm',
#  'debt',
#  '62139',
#  '668n',
#  'accounts',
#  'payable',
#  '205217',
#  '105580n',
#  'current',
#  'liabilities',
#  '179373',
#  '91851n',
#  'n',
#  'total',
#  'current',
#  'liabilities',
#  '446729',
#  '198099nlongterm',
#  'debt',
#  '1637820',
#  '194580nother',
#  'longterm',
#  'liabilities',
#  '189660',
#  '141109ndeferred',
#  'income',
#  'taxes',
#  '79674',
#  '54559nminority',
#  'interest',
#  '55191',
#  'nncommitments',
#  'contingencies',
#  'note',
#  '6nnshareholders',
#  'equityn',
#  'common',
#  'stock',
#  'issued',
#  '100824578',
#  '89984425',
#  'shares',
#  '1008',
#  '900n',
#  'accumulated',
#  'comprehensive',
#  'loss',
#  '29288',
#  '28722n',
#  'shareholders',
#  'equity',
#  '1062628',
#  '622804n',
#  'n',
#  '1034348',
#  '594982n',
#  'treasury',
#  'stock',
#  'cost',
#  '4454394',
#  'shares',
#  '1997',
#  '63045n',
#  'n',
#  'total',
#  'shareholders',
#  'equity',
#  '1034348',
#  '531937n',
#  'n',
#  '3443422',
#  '1120284n',
#  'ntablenn',
#  'see',
#  'notes',
#  'condensed',
#  'consolidated',
#  'financial',
#  'statementsnn',
#  '3npagenn',
#  'sunbeam',
#  'corporation',
#  'subsidiariesnn',
#  'condensed',
#  'consolidated',
#  'statements',
#  'cash',
#  'flowsn',
#  'dollars',
#  'thousandsnntablencaptionn',
#  'three',
#  'months',
#  'endedn',
#  'n',
#  'march',
#  '31',
#  'march',
#  '30n',
#  '1998',
#  '1997n',
#  'n',
#  'unauditedns',
#  'c',
#  'cnoperating',
#  'activitiesn',
#  'net',
#  'earnings',
#  'loss',
#  '44593',
#  '6848n',
#  'adjustments',
#  'reconcile',
#  'net',
#  'earnings',
#  'loss',
#  'net',
#  'cashn',
#  'used',
#  'operating',
#  'activitiesn',
#  'depreciation',
#  'amortization',
#  '11400',
#  '10587n',
#  'deferred',
#  'income',
#  'taxes',
#  '4785',
#  '13128n',
#  'extraordinary',
#  'charge',
#  'early',
#  'extinguishment',
#  'debt',
#  'net',
#  'taxes',
#  '5608',
#  'n',
#  'noncash',
#  'special',
#  'compensation',
#  'charges',
#  '24290',
#  'n',
#  'loss',
#  'sale',
#  'discontinued',
#  'operations',
#  'net',
#  'taxes',
#  '13713n',
#  'changes',
#  'working',
#  'capital',
#  'including',
#  'restructuring',
#  'spending',
#  '135786',
#  '66969n',
#  'n',
#  'net',
#  'cash',
#  'used',
#  'operating',
#  'activities',
#  '143866',
#  '22693n',
#  'ninvesting',
#  'activitiesn',
#  'capital',
#  'expenditures',
#  'net',
#  '10420',
#  '10821n',
#  'acquisition',
#  'cln',
#  'holdings',
#  'inc',
#  'net',
#  'cash',
#  'acquired',
#  '160612',
#  'n',
#  'proceeds',
#  'sales',
#  'divested',
#  'operations',
#  'assets',
#  '70404n',
#  'n',
#  'net',
#  'cash',
#  'provided',
#  'used',
#  'investing',
#  'activities',
#  '171032',
#  '59583n',
#  'nfinancing',
#  'activitiesn',
#  'issuance',
#  'convertible',
#  'subordinated',
#  'debentures',
#  'net',
#  'financing',
#  'fees',
#  '729622',
#  'n',
#  'payments',
#  'debt',
#  'obligations',
#  'including',
#  'prepayment',
#  'penalties',
#  '266672',
#  '26322n',
#  'debt',
#  'financing',
#  'fees',
#  '25075',
#  'n',
#  'proceeds',
#  'exercise',
#  'stock',
#  'options',
#  '19045',
#  '8866n',
#  'net',
#  '857',
#  '545n',
#  'n',
#  'net',
#  'cash',
#  'provided',
#  'used',
#  'financing',
#  'activities',
#  '456063',
#  '18001n',
#  'nnet',
#  'increase',
#  'cash',
#  'cash',
#  'equivalents',
#  '141165',
#  '18889ncash',
#  'cash',
#  'equivalents',
#  'beginning',
#  'period',
#  '52378',
#  '11526n',
#  'ncash',
#  'cash',
#  'equivalents',
#  'end',
#  'period',
#  '193543',
#  '30415n',
#  'ntablenn',
#  'see',
#  'notes',
#  'condensed',
#  'consolidated',
#  'financial',
#  'statementsnn',
#  '4npagenn',
#  'sunbeam',
#  'corporation',
#  'subsidiariesnn',
#  'notes',
#  'condensed',
#  'consolidated',
#  'financial',
#  'statementsn',
#  'unauditednn1',
#  'operations',
#  'basis',
#  'presentationnn',
#  'sunbeam',
#  'corporation',
#  'company',
#  'a',
#  'leading',
#  'designer',
#  'manufacturernand',
#  'marketer',
#  'consumer',
#  'branded',
#  'products',
#  'sunbeamregistered',
#  'trademarknand',
#  'osterregistered',
#  'trademark',
#  'brands',
#  'household',
#  'names',
#  'forngenerations',
#  'company',
#  'a',
#  'market',
#  'share',
#  'leader',
#  'many',
#  'productncategoriesnn',
#  'company',
#  'markets',
#  'products',
#  'virtually',
#  'every',
#  'category',
#  'ofnretailer',
#  'including',
#  'mass',
#  'merchandisers',
#  'catalog',
#  'showrooms',
#  'warehouse',
#  'clubsndepartment',
#  'stores',
#  'catalogs',
#  'companyowned',
#  'outlet',
#  'stores',
#  'television',
#  'shoppingnchannels',
#  'hardware',
#  'stores',
#  'home',
#  'centers',
#  'drug',
#  'grocery',
#  'stores',
#  'pet',
#  'supplynretailers',
#  'well',
#  'independent',
#  'distributors',
#  'military',
#  'companynalso',
#  'sells',
#  'products',
#  'commercial',
#  'endusers',
#  'hotels',
#  'otherninstitutionsnn',
#  'described',
#  'note',
#  '2',
#  'march',
#  '30',
#  '1998',
#  'a',
#  'wholly',
#  'ownednsubsidiary',
#  'company',
#  'acquired',
#  'cln',
#  'holdings',
#  'inc',
#  'cln',
#  'holdings',
#  'anresult',
#  'acquisition',
#  'cln',
#  'holdings',
#  'company',
#  'became',
#  'indirectnowner',
#  'approximately',
#  '809',
#  'total',
#  'number',
#  'outstanding',
#  'shares',
#  'ofnthe',
#  'coleman',
#  'company',
#  'inc',
#  'coleman',
#  'coleman',
#  'a',
#  'leading',
#  'manufacturer',
#  'andnmarketer',
#  'consumer',
#  'products',
#  'worldwide',
#  'outdoor',
#  'recreation',
#  'market',
#  'itsnproducts',
#  'sold',
#  ...]

# %%
master_dict = pd.read_excel('/content/drive/MyDrive/Datasets/LoughranMcDonald_MasterDictionary_2020.xlsx')
master_dict.head()
# Out:
#         Word  Seq_num  Word Count  ...  Complexity  Syllables     Source
# 0   AARDVARK        1         312  ...           0          2  12of12inf
# 1  AARDVARKS        2           3  ...           0          2  12of12inf
# 2      ABACI        3           9  ...           0          3  12of12inf
# 3      ABACK        4          15  ...           0          2  12of12inf
# 4     ABACUS        5        8009  ...           0          3  12of12inf
#
# [5 rows x 17 columns]

# %%
master_dict['Negative'].value_counts()
# Out:
#  0       84176
#  2009     2305
#  2014       26
#  2011       13
# -2020       10
#  2012        1
# Name: Negative, dtype: int64

# %%
master_dict['Positive'].value_counts()
# Out:
#  0       86177
#  2009      345
# -2020        7
#  2012        1
#  2011        1
# Name: Positive, dtype: int64

# %%
positive_np = master_dict['Word'][master_dict.Positive>0].tolist()
#positive_np = positive_dict.to_numpy()
positive_np = [word.lower() for word in positive_np]
positive_np
# Out:
# ['able',
#  'abundance',
#  'abundant',
#  'acclaimed',
#  'accomplish',
#  'accomplished',
#  'accomplishes',
#  'accomplishing',
#  'accomplishment',
#  'accomplishments',
#  'achieve',
#  'achieved',
#  'achievement',
#  'achievements',
#  'achieves',
#  'achieving',
#  'adequately',
#  'advancement',
#  'advancements',
#  'advances',
#  'advancing',
#  'advantage',
#  'advantaged',
#  'advantageous',
#  'advantageously',
#  'advantages',
#  'alliance',
#  'alliances',
#  'assure',
#  'assured',
#  'assures',
#  'assuring',
#  'attain',
#  'attained',
#  'attaining',
#  'attainment',
#  'attainments',
#  'attains',
#  'attractive',
#  'attractiveness',
#  'beautiful',
#  'beautifully',
#  'beneficially',
#  'benefited',
#  'benefiting',
#  'benefitted',
#  'benefitting',
#  'best',
#  'better',
#  'bolstered',
#  'bolstering',
#  'bolsters',
#  'boom',
#  'booming',
#  'boost',
#  'boosted',
#  'breakthrough',
#  'breakthroughs',
#  'brilliant',
#  'charitable',
#  'collaborate',
#  'collaborated',
#  'collaborates',
#  'collaborating',
#  'collaboration',
#  'collaborations',
#  'collaborative',
#  'collaborator',
#  'collaborators',
#  'compliment',
#  'complimentary',
#  'complimented',
#  'complimenting',
#  'compliments',
#  'conclusive',
#  'conclusively',
#  'conducive',
#  'confident',
#  'constructive',
#  'constructively',
#  'courteous',
#  'creative',
#  'creatively',
#  'creativeness',
#  'creativity',
#  'delight',
#  'delighted',
#  'delightful',
#  'delightfully',
#  'delighting',
#  'delights',
#  'dependability',
#  'dependable',
#  'desirable',
#  'desired',
#  'despite',
#  'destined',
#  'diligent',
#  'diligently',
#  'distinction',
#  'distinctions',
#  'distinctive',
#  'distinctively',
#  'distinctiveness',
#  'dream',
#  'easier',
#  'easily',
#  'easy',
#  'efficiencies',
#  'efficiency',
#  'efficient',
#  'efficiently',
#  'empower',
#  'empowered',
#  'empowering',
#  'empowers',
#  'enable',
#  'enabled',
#  'enables',
#  'enabling',
#  'encouraged',
#  'encouragement',
#  'encourages',
#  'encouraging',
#  'enhance',
#  'enhanced',
#  'enhancement',
#  'enhancements',
#  'enhances',
#  'enhancing',
#  'enjoy',
#  'enjoyable',
#  'enjoyably',
#  'enjoyed',
#  'enjoying',
#  'enjoyment',
#  'enjoys',
#  'enthusiasm',
#  'enthusiastic',
#  'enthusiastically',
#  'excellence',
#  'excellent',
#  'excelling',
#  'excels',
#  'exceptional',
#  'exceptionally',
#  'excited',
#  'excitement',
#  'exciting',
#  'exclusive',
#  'exclusively',
#  'exclusiveness',
#  'exclusives',
#  'exclusivity',
#  'exemplary',
#  'fantastic',
#  'favorable',
#  'favorably',
#  'favored',
#  'favoring',
#  'favorite',
#  'favorites',
#  'friendly',
#  'gain',
#  'gained',
#  'gaining',
#  'gains',
#  'good',
#  'greatest',
#  'greatly',
#  'greatness',
#  'happiest',
#  'happily',
#  'happiness',
#  'happy',
#  'highest',
#  'honor',
#  'honored',
#  'honoring',
#  'honors',
#  'ideal',
#  'impress',
#  'impressed',
#  'impresses',
#  'impressing',
#  'impressive',
#  'impressively',
#  'improve',
#  'improved',
#  'improvement',
#  'improvements',
#  'improves',
#  'improving',
#  'incredible',
#  'incredibly',
#  'influential',
#  'informative',
#  'ingenuity',
#  'innovate',
#  'innovated',
#  'innovates',
#  'innovating',
#  'innovation',
#  'innovations',
#  'innovative',
#  'innovativeness',
#  'innovator',
#  'innovators',
#  'insightful',
#  'inspiration',
#  'inspirational',
#  'integrity',
#  'invent',
#  'invented',
#  'inventing',
#  'invention',
#  'inventions',
#  'inventive',
#  'inventiveness',
#  'inventor',
#  'inventors',
#  'leadership',
#  'leading',
#  'loyal',
#  'lucrative',
#  'meritorious',
#  'opportunities',
#  'opportunity',
#  'optimistic',
#  'outperform',
#  'outperformed',
#  'outperforming',
#  'outperforms',
#  'perfect',
#  'perfected',
#  'perfectly',
#  'perfects',
#  'pleasant',
#  'pleasantly',
#  'pleased',
#  'pleasure',
#  'plentiful',
#  'popular',
#  'popularity',
#  'positive',
#  'positively',
#  'preeminence',
#  'preeminent',
#  'premier',
#  'premiere',
#  'prestige',
#  'prestigious',
#  'proactive',
#  'proactively',
#  'proficiency',
#  'proficient',
#  'proficiently',
#  'profitability',
#  'profitable',
#  'profitably',
#  'progress',
#  'progressed',
#  'progresses',
#  'progressing',
#  'prospered',
#  'prospering',
#  'prosperity',
#  'prosperous',
#  'prospers',
#  'rebound',
#  'rebounded',
#  'rebounding',
#  'receptive',
#  'regain',
#  'regained',
#  'regaining',
#  'resolve',
#  'revolutionize',
#  'revolutionized',
#  'revolutionizes',
#  'revolutionizing',
#  'reward',
#  'rewarded',
#  'rewarding',
#  'satisfaction',
#  'satisfactorily',
#  'satisfactory',
#  'satisfied',
#  'satisfies',
#  'satisfy',
#  'satisfying',
#  'smooth',
#  'smoothing',
#  'smoothly',
#  'smooths',
#  'solves',
#  'solving',
#  'spectacular',
#  'spectacularly',
#  'stability',
#  'stabilization',
#  'stabilizations',
#  'stabilize',
#  'stabilized',
#  'stabilizes',
#  'stabilizing',
#  'stable',
#  'strength',
#  'strengthen',
#  'strengthened',
#  'strengthening',
#  'strengthens',
#  'strengths',
#  'strong',
#  'stronger',
#  'strongest',
#  'succeed',
#  'succeeded',
#  'succeeding',
#  'succeeds',
#  'success',
#  'successes',
#  'successful',
#  'successfully',
#  'superior',
#  'surpass',
#  'surpassed',
#  'surpasses',
#  'surpassing',
#  'transparency',
#  'tremendous',
#  'tremendously',
#  'unmatched',
#  'unparalleled',
#  'unsurpassed',
#  'upturn',
#  'upturns',
#  'valuable',
#  'versatile',
#  'versatility',
#  'vibrancy',
#  'vibrant',
#  'win',
#  'winner',
#  'winners',
#  'winning',
#  'worthy']

# %%
negative_np = master_dict['Word'][master_dict.Negative>0].tolist()
#negative_np = negative_dict.to_numpy().tolist()
negative_np = np.array(negative_np)
negative_np = [word.lower() for word in negative_np]
negative_np
# Out:
# ['abandon',
#  'abandoned',
#  'abandoning',
#  'abandonment',
#  'abandonments',
#  'abandons',
#  'abdicated',
#  'abdicates',
#  'abdicating',
#  'abdication',
#  'abdications',
#  'aberrant',
#  'aberration',
#  'aberrational',
#  'aberrations',
#  'abetting',
#  'abnormal',
#  'abnormalities',
#  'abnormality',
#  'abnormally',
#  'abolish',
#  'abolished',
#  'abolishes',
#  'abolishing',
#  'abrogate',
#  'abrogated',
#  'abrogates',
#  'abrogating',
#  'abrogation',
#  'abrogations',
#  'abrupt',
#  'abruptly',
#  'abruptness',
#  'absence',
#  'absences',
#  'absenteeism',
#  'abuse',
#  'abused',
#  'abuses',
#  'abusing',
#  'abusive',
#  'abusively',
#  'abusiveness',
#  'accident',
#  'accidental',
#  'accidentally',
#  'accidents',
#  'accusation',
#  'accusations',
#  'accuse',
#  'accused',
#  'accuses',
#  'accusing',
#  'acquiesce',
#  'acquiesced',
#  'acquiesces',
#  'acquiescing',
#  'acquit',
#  'acquits',
#  'acquittal',
#  'acquittals',
#  'acquitted',
#  'acquitting',
#  'adulterate',
#  'adulterated',
#  'adulterating',
#  'adulteration',
#  'adulterations',
#  'adversarial',
#  'adversaries',
#  'adversary',
#  'adverse',
#  'adversely',
#  'adversities',
#  'adversity',
#  'aftermath',
#  'aftermaths',
#  'against',
#  'aggravate',
#  'aggravated',
#  'aggravates',
#  'aggravating',
#  'aggravation',
#  'aggravations',
#  'alerted',
#  'alerting',
#  'alienate',
#  'alienated',
#  'alienates',
#  'alienating',
#  'alienation',
#  'alienations',
#  'allegation',
#  'allegations',
#  'allege',
#  'alleged',
#  'allegedly',
#  'alleges',
#  'alleging',
#  'annoy',
#  'annoyance',
#  'annoyances',
#  'annoyed',
#  'annoying',
#  'annoys',
#  'annul',
#  'annulled',
#  'annulling',
#  'annulment',
#  'annulments',
#  'annuls',
#  'anomalies',
#  'anomalous',
#  'anomalously',
#  'anomaly',
#  'anticompetitive',
#  'antitrust',
#  'argue',
#  'argued',
#  'arguing',
#  'argument',
#  'argumentative',
#  'arguments',
#  'arrearage',
#  'arrearages',
#  'arrears',
#  'arrest',
#  'arrested',
#  'arrests',
#  'artificially',
#  'assault',
#  'assaulted',
#  'assaulting',
#  'assaults',
#  'assertions',
#  'attrition',
#  'aversely',
#  'backdating',
#  'bad',
#  'bail',
#  'bailout',
#  'balk',
#  'balked',
#  'bankrupt',
#  'bankruptcies',
#  'bankruptcy',
#  'bankrupted',
#  'bankrupting',
#  'bankrupts',
#  'bans',
#  'barred',
#  'barrier',
#  'barriers',
#  'bottleneck',
#  'bottlenecks',
#  'boycott',
#  'boycotted',
#  'boycotting',
#  'boycotts',
#  'breach',
#  'breached',
#  'breaches',
#  'breaching',
#  'break',
#  'breakage',
#  'breakages',
#  'breakdown',
#  'breakdowns',
#  'breaks',
#  'bribe',
#  'bribed',
#  'briberies',
#  'bribery',
#  'bribes',
#  'bribing',
#  'burden',
#  'burdened',
#  'burdening',
#  'burdens',
#  'burdensome',
#  'burned',
#  'calamities',
#  'calamitous',
#  'calamity',
#  'cancel',
#  'canceled',
#  'canceling',
#  'cancellation',
#  'cancellations',
#  'cancelled',
#  'cancelling',
#  'cancels',
#  'careless',
#  'carelessly',
#  'carelessness',
#  'catastrophe',
#  'catastrophes',
#  'catastrophic',
#  'catastrophically',
#  'caution',
#  'cautionary',
#  'cautioned',
#  'cautioning',
#  'cautions',
#  'cease',
#  'ceased',
#  'ceases',
#  'ceasing',
#  'censure',
#  'censured',
#  'censures',
#  'censuring',
#  'challenge',
#  'challenged',
#  'challenges',
#  'challenging',
#  'chargeoffs',
#  'circumvent',
#  'circumvented',
#  'circumventing',
#  'circumvention',
#  'circumventions',
#  'circumvents',
#  'claiming',
#  'claims',
#  'clawback',
#  'closeout',
#  'closeouts',
#  'closings',
#  'closure',
#  'closures',
#  'coerce',
#  'coerced',
#  'coerces',
#  'coercing',
#  'coercion',
#  'coercive',
#  'collapse',
#  'collapsed',
#  'collapses',
#  'collapsing',
#  'collision',
#  'collisions',
#  'collude',
#  'colluded',
#  'colludes',
#  'colluding',
#  'collusion',
#  'collusions',
#  'collusive',
#  'complain',
#  'complained',
#  'complaining',
#  'complains',
#  'complaint',
#  'complaints',
#  'complicate',
#  'complicated',
#  'complicates',
#  'complicating',
#  'complication',
#  'complications',
#  'compulsion',
#  'concealed',
#  'concealing',
#  'concede',
#  'conceded',
#  'concedes',
#  'conceding',
#  'concern',
#  'concerned',
#  'concerns',
#  'conciliating',
#  'conciliation',
#  'conciliations',
#  'condemn',
#  'condemnation',
#  'condemnations',
#  'condemned',
#  'condemning',
#  'condemns',
#  'condone',
#  'condoned',
#  'confess',
#  'confessed',
#  'confesses',
#  'confessing',
#  'confession',
#  'confine',
#  'confined',
#  'confinement',
#  'confinements',
#  'confines',
#  'confining',
#  'confiscate',
#  'confiscated',
#  'confiscates',
#  'confiscating',
#  'confiscation',
#  'confiscations',
#  'conflict',
#  'conflicted',
#  'conflicting',
#  'conflicts',
#  'confront',
#  'confrontation',
#  'confrontational',
#  'confrontations',
#  'confronted',
#  'confronting',
#  'confronts',
#  'confuse',
#  'confused',
#  'confuses',
#  'confusing',
#  'confusingly',
#  'confusion',
#  'conspiracies',
#  'conspiracy',
#  'conspirator',
#  'conspiratorial',
#  'conspirators',
#  'conspire',
#  'conspired',
#  'conspires',
#  'conspiring',
#  'contempt',
#  'contend',
#  'contended',
#  'contending',
#  'contends',
#  'contention',
#  'contentions',
#  'contentious',
#  'contentiously',
#  'contested',
#  'contesting',
#  'contraction',
#  'contractions',
#  'contradict',
#  'contradicted',
#  'contradicting',
#  'contradiction',
#  'contradictions',
#  'contradictory',
#  'contradicts',
#  'contrary',
#  'controversial',
#  'controversies',
#  'controversy',
#  'convict',
#  'convicted',
#  'convicting',
#  'conviction',
#  'convictions',
#  'corrected',
#  'correcting',
#  'correction',
#  'corrections',
#  'corrects',
#  'corrupt',
#  'corrupted',
#  'corrupting',
#  'corruption',
#  'corruptions',
#  'corruptly',
#  'corruptness',
#  'costly',
#  'counterclaim',
#  'counterclaimed',
#  'counterclaiming',
#  'counterclaims',
#  'counterfeit',
#  'counterfeited',
#  'counterfeiter',
#  'counterfeiters',
#  'counterfeiting',
#  'counterfeits',
#  'countermeasure',
#  'countermeasures',
#  'crime',
#  'crimes',
#  'criminal',
#  'criminally',
#  'criminals',
#  'crises',
#  'crisis',
#  'critically',
#  'criticism',
#  'criticisms',
#  'criticize',
#  'criticized',
#  'criticizes',
#  'criticizing',
#  'crucial',
#  'crucially',
#  'culpability',
#  'culpable',
#  'culpably',
#  'cumbersome',
#  'curtail',
#  'curtailed',
#  'curtailing',
#  'curtailment',
#  'curtailments',
#  'curtails',
#  'cut',
#  'cutback',
#  'cutbacks',
#  'cyberattack',
#  'cyberattacks',
#  'cyberbullying',
#  'cybercrime',
#  'cybercrimes',
#  'cybercriminal',
#  'cybercriminals',
#  'damage',
#  'damaged',
#  'damages',
#  'damaging',
#  'dampen',
#  'dampened',
#  'danger',
#  'dangerous',
#  'dangerously',
#  'dangers',
#  'deadlock',
#  'deadlocked',
#  'deadlocking',
#  'deadlocks',
#  'deadweight',
#  'deadweights',
#  'debarment',
#  'debarments',
#  'debarred',
#  'deceased',
#  'deceit',
#  'deceitful',
#  'deceitfulness',
#  'deceive',
#  'deceived',
#  'deceives',
#  'deceiving',
#  'deception',
#  'deceptions',
#  'deceptive',
#  'deceptively',
#  'decline',
#  'declined',
#  'declines',
#  'declining',
#  'deface',
#  'defaced',
#  'defacement',
#  'defamation',
#  'defamations',
#  'defamatory',
#  'defame',
#  'defamed',
#  'defames',
#  'defaming',
#  'default',
#  'defaulted',
#  'defaulting',
#  'defaults',
#  'defeat',
#  'defeated',
#  'defeating',
#  'defeats',
#  'defect',
#  'defective',
#  'defects',
#  'defend',
#  'defendant',
#  'defendants',
#  'defended',
#  'defending',
#  'defends',
#  'defensive',
#  'defer',
#  'deficiencies',
#  'deficiency',
#  'deficient',
#  'deficit',
#  'deficits',
#  'defraud',
#  'defrauded',
#  'defrauding',
#  'defrauds',
#  'defunct',
#  'degradation',
#  'degradations',
#  'degrade',
#  'degraded',
#  'degrades',
#  'degrading',
#  'delay',
#  'delayed',
#  'delaying',
#  'delays',
#  'deleterious',
#  'deliberate',
#  'deliberated',
#  'deliberately',
#  'delinquencies',
#  'delinquency',
#  'delinquent',
#  'delinquently',
#  'delinquents',
#  'delist',
#  'delisted',
#  'delisting',
#  'delists',
#  'demise',
#  'demised',
#  'demises',
#  'demising',
#  'demolish',
#  'demolished',
#  'demolishes',
#  'demolishing',
#  'demolition',
#  'demolitions',
#  'demote',
#  'demoted',
#  'demotes',
#  'demoting',
#  'demotion',
#  'demotions',
#  'denial',
#  'denials',
#  'denied',
#  'denies',
#  'denigrate',
#  'denigrated',
#  'denigrates',
#  'denigrating',
#  'denigration',
#  'deny',
#  'denying',
#  'deplete',
#  'depleted',
#  'depletes',
#  'depleting',
#  'depletion',
#  'depletions',
#  'deprecation',
#  'depress',
#  'depressed',
#  'depresses',
#  'depressing',
#  'deprivation',
#  'deprive',
#  'deprived',
#  'deprives',
#  'depriving',
#  'derelict',
#  'dereliction',
#  'derogatory',
#  'destabilization',
#  'destabilize',
#  'destabilized',
#  'destabilizing',
#  'destroy',
#  'destroyed',
#  'destroying',
#  'destroys',
#  'destruction',
#  'destructive',
#  'detain',
#  'detained',
#  'detention',
#  'detentions',
#  'deter',
#  'deteriorate',
#  'deteriorated',
#  'deteriorates',
#  'deteriorating',
#  'deterioration',
#  'deteriorations',
#  'deterred',
#  'deterrence',
#  'deterrences',
#  'deterrent',
#  'deterrents',
#  'deterring',
#  'deters',
#  'detract',
#  'detracted',
#  'detracting',
#  'detriment',
#  'detrimental',
#  'detrimentally',
#  'detriments',
#  'devalue',
#  'devalued',
#  'devalues',
#  'devaluing',
#  'devastate',
#  'devastated',
#  'devastating',
#  'devastation',
#  'deviate',
#  'deviated',
#  'deviates',
#  'deviating',
#  'deviation',
#  'deviations',
#  'devolve',
#  'devolved',
#  'devolves',
#  'devolving',
#  'difficult',
#  'difficulties',
#  'difficultly',
#  'difficulty',
#  'diminish',
#  'diminished',
#  'diminishes',
#  'diminishing',
#  'diminution',
#  'disadvantage',
#  'disadvantaged',
#  'disadvantageous',
#  'disadvantages',
#  'disaffiliation',
#  'disagree',
#  'disagreeable',
#  'disagreed',
#  'disagreeing',
#  'disagreement',
#  'disagreements',
#  'disagrees',
#  'disallow',
#  'disallowance',
#  'disallowances',
#  'disallowed',
#  'disallowing',
#  'disallows',
#  'disappear',
#  'disappearance',
#  'disappearances',
#  'disappeared',
#  'disappearing',
#  'disappears',
#  'disappoint',
#  'disappointed',
#  'disappointing',
#  'disappointingly',
#  'disappointment',
#  'disappointments',
#  'disappoints',
#  'disapproval',
#  'disapprovals',
#  'disapprove',
#  'disapproved',
#  'disapproves',
#  'disapproving',
#  'disassociates',
#  'disassociating',
#  'disassociation',
#  'disassociations',
#  'disaster',
#  'disasters',
#  'disastrous',
#  'disastrously',
#  'disavow',
#  'disavowal',
#  'disavowed',
#  'disavowing',
#  'disavows',
#  'disciplinary',
#  'disclaim',
#  'disclaimed',
#  'disclaimer',
#  'disclaimers',
#  'disclaiming',
#  'disclaims',
#  'disclose',
#  'disclosed',
#  'discloses',
#  'disclosing',
#  'discontinuance',
#  'discontinuances',
#  'discontinuation',
#  'discontinuations',
#  'discontinue',
#  'discontinued',
#  'discontinues',
#  'discontinuing',
#  'discourage',
#  'discouraged',
#  'discourages',
#  'discouraging',
#  'discredit',
#  'discredited',
#  'discrediting',
#  'discredits',
#  'discrepancies',
#  'discrepancy',
#  'disfavor',
#  'disfavored',
#  'disfavoring',
#  'disfavors',
#  'disgorge',
#  'disgorged',
#  'disgorgement',
#  'disgorgements',
#  'disgorges',
#  'disgorging',
#  'disgrace',
#  'disgraceful',
#  'disgracefully',
#  'dishonest',
#  'dishonestly',
#  'dishonesty',
#  'dishonor',
#  'dishonorable',
#  'dishonorably',
#  'dishonored',
#  'dishonoring',
#  'dishonors',
#  'disincentives',
#  'disinterested',
#  'disinterestedly',
#  'disinterestedness',
#  'disloyal',
#  'disloyally',
#  'disloyalty',
#  'dismal',
#  'dismally',
#  'dismiss',
#  'dismissal',
#  'dismissals',
#  'dismissed',
#  'dismisses',
#  'dismissing',
#  'disorderly',
#  'disparage',
#  'disparaged',
#  'disparagement',
#  'disparagements',
#  'disparages',
#  'disparaging',
#  'disparagingly',
#  'disparities',
#  'disparity',
#  'displace',
#  'displaced',
#  'displacement',
#  'displacements',
#  'displaces',
#  'displacing',
#  'dispose',
#  'dispossess',
#  'dispossessed',
#  'dispossesses',
#  'dispossessing',
#  'disproportion',
#  'disproportional',
#  'disproportionate',
#  'disproportionately',
#  'dispute',
#  'disputed',
#  'disputes',
#  'disputing',
#  'disqualification',
#  'disqualifications',
#  'disqualified',
#  'disqualifies',
#  'disqualify',
#  'disqualifying',
#  'disregard',
#  'disregarded',
#  'disregarding',
#  'disregards',
#  'disreputable',
#  'disrepute',
#  'disrupt',
#  'disrupted',
#  'disrupting',
#  'disruption',
#  'disruptions',
#  'disruptive',
#  'disrupts',
#  'dissatisfaction',
#  'dissatisfied',
#  'dissent',
#  'dissented',
#  'dissenter',
#  'dissenters',
#  'dissenting',
#  'dissents',
#  'dissident',
#  'dissidents',
#  'dissolution',
#  'dissolutions',
#  'distort',
#  'distorted',
#  'distorting',
#  'distortion',
#  'distortions',
#  'distorts',
#  'distract',
#  'distracted',
#  'distracting',
#  'distraction',
#  'distractions',
#  'distracts',
#  'distress',
#  'distressed',
#  'disturb',
#  'disturbance',
#  'disturbances',
#  'disturbed',
#  'disturbing',
#  'disturbs',
#  'diversion',
#  'divert',
#  'diverted',
#  'diverting',
#  'diverts',
#  'divest',
#  'divested',
#  'divesting',
#  'divestiture',
#  'divestitures',
#  'divestment',
#  'divestments',
#  'divests',
#  'divorce',
#  'divorced',
#  'divulge',
#  'divulged',
#  'divulges',
#  'divulging',
#  'doubt',
#  'doubted',
#  'doubtful',
#  'doubts',
#  'downgrade',
#  'downgraded',
#  'downgrades',
#  'downgrading',
#  'downsize',
#  'downsized',
#  'downsizes',
#  'downsizing',
#  'downsizings',
#  'downtime',
#  'downtimes',
#  'downturn',
#  'downturns',
#  'downward',
#  'downwards',
#  'drag',
#  'drastic',
#  'drastically',
#  'drawback',
#  'drawbacks',
#  'dropped',
#  'drought',
#  'droughts',
#  'duress',
#  'dysfunction',
#  'dysfunctional',
#  'dysfunctions',
#  'easing',
#  'egregious',
#  'egregiously',
#  'embargo',
#  'embargoed',
#  'embargoes',
#  'embargoing',
#  'embarrass',
#  'embarrassed',
#  'embarrasses',
#  'embarrassing',
#  'embarrassment',
#  'embarrassments',
#  'embezzle',
#  'embezzled',
#  'embezzlement',
#  'embezzlements',
#  'embezzler',
#  'embezzles',
#  'embezzling',
#  'encroach',
#  'encroached',
#  'encroaches',
#  'encroaching',
#  'encroachment',
#  'encroachments',
#  'encumber',
#  'encumbered',
#  'encumbering',
#  'encumbers',
#  'encumbrance',
#  'encumbrances',
#  'endanger',
#  'endangered',
#  'endangering',
#  'endangerment',
#  'endangers',
#  'enjoin',
#  'enjoined',
#  'enjoining',
#  'enjoins',
#  'erode',
#  'eroded',
#  'erodes',
#  'eroding',
#  'erosion',
#  'erratic',
#  'erratically',
#  'erred',
#  'erring',
#  'erroneous',
#  'erroneously',
#  'error',
#  'errors',
#  'errs',
#  'escalate',
#  'escalated',
#  'escalates',
#  'escalating',
#  'evade',
#  'evaded',
#  'evades',
#  'evading',
#  'evasion',
#  'evasions',
#  'evasive',
#  'evict',
#  'evicted',
#  'evicting',
#  'eviction',
#  'evictions',
#  'evicts',
#  'exacerbate',
#  'exacerbated',
#  'exacerbates',
#  'exacerbating',
#  'exacerbation',
#  'exacerbations',
#  'exaggerate',
#  'exaggerated',
#  'exaggerates',
#  'exaggerating',
#  'exaggeration',
#  'excessive',
#  'excessively',
#  'exculpate',
#  'exculpated',
#  'exculpates',
#  'exculpating',
#  'exculpation',
#  'exculpations',
#  'exculpatory',
#  'exonerate',
#  'exonerated',
#  'exonerates',
#  'exonerating',
#  'exoneration',
#  'exonerations',
#  'exploit',
#  'exploitation',
#  'exploitations',
#  'exploitative',
#  'exploited',
#  'exploiting',
#  'exploits',
#  'expose',
#  'exposed',
#  'exposes',
#  'exposing',
#  'expropriate',
#  'expropriated',
#  'expropriates',
#  'expropriating',
#  'expropriation',
#  'expropriations',
#  'expulsion',
#  'expulsions',
#  'extenuating',
#  'fail',
#  'failed',
#  'failing',
#  'failings',
#  'fails',
#  'failure',
#  'failures',
#  'fallout',
#  'false',
#  'falsely',
#  'falsification',
#  'falsifications',
#  'falsified',
#  'falsifies',
#  'falsify',
#  ...]

# %%
def positive_score(tokens):
    count = 0

    for word in tokens:
      if word in positive_np:
        count+=1
    return count

df['positive_score'] = df['report_no_stopwords'].apply(lambda x: positive_score(x))

df.head()
# Out:
#    Unnamed: 0  ...  positive_score
# 0           0  ...              35
# 1           1  ...               4
# 2           2  ...               0
# 3           3  ...               9
# 4           4  ...               1
#
# [5 rows x 11 columns]

# %%
def negative_score(tokens):
    count = 0
    for word in tokens:
      if word in negative_np:
        count+=1
    return count

df['negative_score'] = df['report_no_stopwords'].apply(lambda x: negative_score(x))

df.head()
# Out:
#    Unnamed: 0   CIK  ... positive_score  negative_score
# 0           0  3662  ...             35              17
# 1           1  3662  ...              4              24
# 2           2  3662  ...              0               7
# 3           3  3662  ...              9             123
# 4           4  3662  ...              1               7
#
# [5 rows x 12 columns]

# %%
for index, row in df.iterrows():
  df.loc[index, 'polarity_score'] = (row['positive_score']-row['negative_score'])/((row['positive_score']+row['negative_score'])+0.000001)

# %%
df.head()
# Out:
#    Unnamed: 0   CIK  ... negative_score  polarity_score
# 0           0  3662  ...             17        0.346154
# 1           1  3662  ...             24       -0.714286
# 2           2  3662  ...              7       -1.000000
# 3           3  3662  ...            123       -0.863636
# 4           4  3662  ...              7       -0.750000
#
# [5 rows x 13 columns]

# %%
df['polarity_score'].value_counts()
# Out:
#  0.000000    30
# -1.000000     9
# -0.846154     4
# -0.833333     4
# -0.999999     4
#              ..
#  0.745455     1
#  0.306122     1
# -0.863636     1
#  0.255814     1
#  0.928571     1
# Name: polarity_score, Length: 93, dtype: int64

# %%
for index, row in df.iterrows():
  df.loc[index, 'subjectivity score'] = (row['positive_score']+row['negative_score'])/(len(row['report_no_stopwords'])+0.000001)

df.head()
# Out:
#    Unnamed: 0   CIK  ... polarity_score  subjectivity score
# 0           0  3662  ...       0.346154            0.019985
# 1           1  3662  ...      -0.714286            0.013665
# 2           2  3662  ...      -1.000000            0.010000
# 3           3  3662  ...      -0.863636            0.047533
# 4           4  3662  ...      -0.750000            0.009627
#
# [5 rows x 14 columns]

# %%
df['subjectivity score'].value_counts()
# Out:
# 0.000000    25
# 0.003541     1
# 0.019151     1
# 0.010011     1
# 0.020748     1
#             ..
# 0.008609     1
# 0.004264     1
# 0.002118     1
# 0.024836     1
# 0.024314     1
# Name: subjectivity score, Length: 128, dtype: int64

# %%
from nltk import sent_tokenize, word_tokenize
#sample_text = 'this is to check. sentence tokeniser. using nltk'
def word_count(text):
  tokens = word_tokenize(text)
  tokens = [tokens for word in tokens if word not in string.punctuation]
  return len(tokens)

# %%
df['word_count'] = df['reports'].apply(lambda x: word_count(x))

# %%
df.head()
# Out:
#    Unnamed: 0   CIK  ... subjectivity score  word_count
# 0           0  3662  ...           0.019985        4259
# 1           1  3662  ...           0.013665        4337
# 2           2  3662  ...           0.010000        1066
# 3           3  3662  ...           0.047533        4542
# 4           4  3662  ...           0.009627        1336
#
# [5 rows x 15 columns]

# %%
def sentence_count(text):
  tokens = sent_tokenize(text)
  tokens = [tokens for sentences in tokens if sentences not in string.punctuation]
  return len(tokens)

# %%
df['sentence_count'] = df['reports'].apply(lambda x: sentence_count(x))

# %%
df.head()
# Out:
#    Unnamed: 0   CIK  ... word_count  sentence_count
# 0           0  3662  ...       4259             103
# 1           1  3662  ...       4337              47
# 2           2  3662  ...       1066              20
# 3           3  3662  ...       4542              91
# 4           4  3662  ...       1336              25
#
# [5 rows x 16 columns]

# %%
for index, row in df.iterrows():
  df.loc[index, 'average_sentence_length'] = (row['word_count']/row['sentence_count'])

# %%
df.head()
# Out:
#    Unnamed: 0   CIK  ... sentence_count  average_sentence_length
# 0           0  3662  ...            103                41.349515
# 1           1  3662  ...             47                92.276596
# 2           2  3662  ...             20                53.300000
# 3           3  3662  ...             91                49.912088
# 4           4  3662  ...             25                53.440000
#
# [5 rows x 17 columns]

# %%
#from nltk.tokenize import LegalitySyllableTokenizer

# %%
def syllable(text):
    #to count syllables
  syllable_list =[]
  #text = "".join([word for word in text if word not in string.punctuation])
  #tokens = re.split('\W+', text)
  #tokens = [tokens.lower() for tokens in text]
  tokens = text.split()
  for word in tokens:
    syllable_count = 0
    vowels = "aeiouy"
    if word[0] in vowels:
        syllable_count += 1
    for index in range(1, len(word)):
        if word[index] in vowels and word[index - 1] not in vowels:
            syllable_count += 1
    if word.endswith("e"):
       syllable_count -= 1
    if syllable_count == 0:
        syllable_count += 1
    syllable_list.append(syllable_count)
  return syllable_list


def add_complex(count_list):
  """this function only adds number of complex words in the given list"""
  complex_count = 0
  for i in count_list:
    if i > 2:
      complex_count += 1
  return complex_count


#print(add_complex(syllable('similarity polarity redemption check output')))

# %%
df['complex_count'] = df['reports'].apply(lambda x:add_complex(syllable(x)))

# %%
df.head()
# Out:
#    Unnamed: 0   CIK  ... average_sentence_length  complex_count
# 0           0  3662  ...               41.349515           1074
# 1           1  3662  ...               92.276596            601
# 2           2  3662  ...               53.300000            145
# 3           3  3662  ...               49.912088           1039
# 4           4  3662  ...               53.440000            186
#
# [5 rows x 18 columns]

# %%
#this is calculated as per given formula in Text Analysis
for index, row in df.iterrows():
  df.loc[index, 'percentage_of_complex_words'] = ((row['complex_count']/row['word_count']))

df.head()
# Out:
#    Unnamed: 0   CIK  ... complex_count  percentage_of_complex_words
# 0           0  3662  ...          1074                     0.252172
# 1           1  3662  ...           601                     0.138575
# 2           2  3662  ...           145                     0.136023
# 3           3  3662  ...          1039                     0.228754
# 4           4  3662  ...           186                     0.139222
#
# [5 rows x 19 columns]

# %%
#df.drop('fog_index',axis =1)

# %%
for index, rows in df.iterrows():
  df.loc[index, 'fog_index'] = (rows['average_sentence_length']+rows['percentage_of_complex_words'])*0.4
df.head()
# Out:
#    Unnamed: 0   CIK  ... percentage_of_complex_words  fog_index
# 0           0  3662  ...                    0.252172  16.640675
# 1           1  3662  ...                    0.138575  36.966068
# 2           2  3662  ...                    0.136023  21.374409
# 3           3  3662  ...                    0.228754  20.056337
# 4           4  3662  ...                    0.139222  21.431689
#
# [5 rows x 20 columns]

# %%
df['percentage_of_complex_words'].value_counts()
# Out:
# 0.075509    1
# 0.142645    1
# 0.105271    1
# 0.114573    1
# 0.048912    1
#            ..
# 0.087662    1
# 0.189818    1
# 0.167273    1
# 0.159311    1
# 0.146739    1
# Name: percentage_of_complex_words, Length: 152, dtype: int64

# %%
for index, rows in df.iterrows():
  df.loc[index, 'complex_word_count'] = rows['complex_count']

df.drop('complex_count', axis =1)
# Out:
#      Unnamed: 0    CIK  ...   fog_index  complex_word_count
# 0             0   3662  ...   16.640675              1074.0
# 1             1   3662  ...   36.966068               601.0
# 2             2   3662  ...   21.374409               145.0
# 3             3   3662  ...   20.056337              1039.0
# 4             4   3662  ...   21.431689               186.0
# ..          ...    ...  ...         ...                 ...
# 147         147  12239  ...  548.567238               922.0
# 148         148  12239  ...  895.110999               744.0
# 149         149  12239  ...  433.648155               783.0
# 150         150  12239  ...  366.867539               929.0
# 151         151  12239  ...  518.527524               770.0
#
# [152 rows x 20 columns]

# %%
columns = df.columns
columns = ['Unnamed: 0', 'CIK', 'CONAME', 'FYRMO', 'FDATE', 'FORM', 'SECFNAME',
       'SECFNAME_complete', 'reports', 'report_no_stopwords', 'positive_score',
       'negative_score', 'Polarity_score', 'Subjectivity score',
       'sentence_count', 'average_sentence_length', 'complex_count',
       'percentage_of_complex_words', 'fog_index', 'complex_word_count','word_count']

df.reindex(columns = columns)
# Out:
#      Unnamed: 0    CIK  ... complex_word_count  word_count
# 0             0   3662  ...             1074.0        4259
# 1             1   3662  ...              601.0        4337
# 2             2   3662  ...              145.0        1066
# 3             3   3662  ...             1039.0        4542
# 4             4   3662  ...              186.0        1336
# ..          ...    ...  ...                ...         ...
# 147         147  12239  ...              922.0        5485
# 148         148  12239  ...              744.0        6713
# 149         149  12239  ...              783.0        6504
# 150         150  12239  ...              929.0        5502
# 151         151  12239  ...              770.0        6481
#
# [152 rows x 21 columns]

# %%
uncertain = pd.read_excel('/content/drive/MyDrive/Datasets/Data Science/uncertainty_dictionary.xlsx')
uncertain.tail()
# Out:
#              Word
# 292          VARY
# 293       VARYING
# 294      VOLATILE
# 295  VOLATILITIES
# 296    VOLATILITY

# %%
uncertain_np = uncertain['Word'].tolist()
#negative_np = negative_dict.to_numpy().tolist()
uncertain_np = np.array(uncertain_np)
uncertain_np = [word.lower() for word in uncertain_np]

def uncertainty_score(tokens):
    count = 0

    for word in tokens:
      if word in uncertain_np:
        count +=1
        
    return count

df['uncertainty_score'] = df['report_no_stopwords'].apply(lambda x: uncertainty_score(x))

# %%
df.head()
# Out:
#    Unnamed: 0   CIK  ... complex_word_count  uncertainty_score
# 0           0  3662  ...             1074.0                 46
# 1           1  3662  ...              601.0                 25
# 2           2  3662  ...              145.0                  9
# 3           3  3662  ...             1039.0                 25
# 4           4  3662  ...              186.0                 10
#
# [5 rows x 22 columns]

# %%
constraining = pd.read_excel('/content/drive/MyDrive/Datasets/Data Science/constraining_dictionary.xlsx')
constraining_np = constraining['Word'].tolist()
#negative_np = negative_dict.to_numpy().tolist()
constraining_np = np.array(constraining_np)
constraining_np = [word.lower() for word in constraining_np]

def constraining_score(tokens):
    count = 0

    for word in tokens:
      if word in constraining_np:
        count +=1
        
    return count

df['constraining_score'] = df['report_no_stopwords'].apply(lambda x: constraining_score(x))
df.head()
# Out:
#    Unnamed: 0   CIK  ... uncertainty_score  constraining_score
# 0           0  3662  ...                46                   4
# 1           1  3662  ...                25                   9
# 2           2  3662  ...                 9                   4
# 3           3  3662  ...                25                  18
# 4           4  3662  ...                10                   4
#
# [5 rows x 23 columns]

# %%
for index, rows in df.iterrows():
  df.loc[index, 'positive_word_proportion'] = rows['positive_score']/rows['word_count']

#df.head()

# %%
for index, rows in df.iterrows():
  df.loc[index, 'negative_word_proportion'] = rows['negative_score']/rows['word_count']

#df.head()

# %%
for index, rows in df.iterrows():
  df.loc[index, 'uncertainty_word_proportion'] = rows['uncertainty_score']/rows['word_count']

#df.head()

# %%
for index, rows in df.iterrows():
  df.loc[index, 'constraining_word_proportion'] = rows['constraining_score']/rows['word_count']

df.head()
# Out:
#    Unnamed: 0   CIK  ... uncertainty_word_proportion  constraining_word_proportion
# 0           0  3662  ...                    0.010801                      0.000939
# 1           1  3662  ...                    0.005764                      0.002075
# 2           2  3662  ...                    0.008443                      0.003752
# 3           3  3662  ...                    0.005504                      0.003963
# 4           4  3662  ...                    0.007485                      0.002994
#
# [5 rows x 27 columns]

# %%
def constraining_list(tokens):
    constraining_list = []

    for word in tokens:
      if word in constraining_np:
        constraining_list.append(word)

    return constraining_list

df['constraining_words_whole_report'] = df['report_no_stopwords'].apply(lambda x: constraining_list(x))
df.head()
# Out:
#    Unnamed: 0  ...                    constraining_words_whole_report
# 0           0  ...         [required, requirements, required, strict]
# 1           1  ...  [required, requirements, obligations, dependin...
# 2           2  ...           [required, required, required, required]
# 3           3  ...  [required, requirements, required, required, d...
# 4           4  ...           [required, required, required, required]
#
# [5 rows x 28 columns]

# %%
column_names = df.columns
len(column_names)
# Out:
# 28

# %%
df.drop(['Unnamed: 0','SECFNAME_complete','reports','report_no_stopwords','complex_count',
        'subjectivity score','complex_count'], axis =1, inplace = True)

# %%
df.drop(['sentence_count'], axis =1, inplace = True)

# %%
df.head()
# Out:
#     CIK  ...                    constraining_words_whole_report
# 0  3662  ...         [required, requirements, required, strict]
# 1  3662  ...  [required, requirements, obligations, dependin...
# 2  3662  ...           [required, required, required, required]
# 3  3662  ...  [required, requirements, required, required, d...
# 4  3662  ...           [required, required, required, required]
#
# [5 rows x 21 columns]

# %%
column_names = df.columns
column_names
# Out:
# Index(['CIK', 'CONAME', 'FYRMO', 'FDATE', 'FORM', 'SECFNAME', 'positive_score',
#        'negative_score', 'polarity_score', 'word_count',
#        'average_sentence_length', 'percentage_of_complex_words', 'fog_index',
#        'complex_word_count', 'uncertainty_score', 'constraining_score',
#        'positive_word_proportion', 'negative_word_proportion',
#        'uncertainty_word_proportion', 'constraining_word_proportion',
#        'constraining_words_whole_report'],
#       dtype='object')

# %%
column_names = ['CONAME',	'FYRMO',	'FDATE',	'FORM',	'SECFNAME',	'positive_score',
                'negative_score',	'polarity_score',	'average_sentence_length',	
                'percentage_of_complex_words',	'fog_index',	'complex_word_count',	
                'word_count',	'uncertainty_score',	'constraining_score',	
                'positive_word_proportion',	'negative_word_proportion',	
                'uncertainty_word_proportion',	'constraining_word_proportion',	
                'constraining_words_whole_report']

# %%
df[column_names]
# Out:
#                CONAME  ...                    constraining_words_whole_report
# 0    SUNBEAM CORP/FL/  ...         [required, requirements, required, strict]
# 1    SUNBEAM CORP/FL/  ...  [required, requirements, obligations, dependin...
# 2    SUNBEAM CORP/FL/  ...           [required, required, required, required]
# 3    SUNBEAM CORP/FL/  ...  [required, requirements, required, required, d...
# 4    SUNBEAM CORP/FL/  ...           [required, required, required, required]
# ..                ...  ...                                                ...
# 147       SPHERIX INC  ...  [required, required, requirements, require, pe...
# 148       SPHERIX INC  ...                                                 []
# 149       SPHERIX INC  ...                 [required, required, requirements]
# 150       SPHERIX INC  ...  [required, required, required, requirements, r...
# 151       SPHERIX INC  ...                 [required, required, requirements]
#
# [152 rows x 20 columns]

# %%
# !pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.0.1-py3-none-any.whl (148 kB)
#      |████████████████████████████████| 148 kB 5.1 MB/s
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.0.1

# %%
df.to_excel('SEC_financialReport.xlsx', sheet_name='TextAnalysis', index=False, engine='xlsxwriter')
